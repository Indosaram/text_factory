# %%
import pandas as pd

from text_factory.topic_modeling import TopicModeling
from text_factory.preprocessing import EnglishPreprocessor

import nltk
from nltk.stem import WordNetLemmatizer

nltk.download('wordnet')
nltk.download('omw-1.4')

df = pd.read_csv("result/edrecovery_tweets.csv")


preprocessor = EnglishPreprocessor()
token_series = preprocessor.tweet_tokenize(
    df["text"], pos_list=["NN", "NNS", "JJ", "JJR", "JJS"]
)
# Out:
# [nltk_data] Downloading package wordnet to /Users/i552267/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
lemmatizer = WordNetLemmatizer()
lemmatized_token_series = preprocessor.lemmatize(lemmatizer, token_series.apply(lambda x:x.split()))

# %%
lemmatized_token_series
# Out:
#                  0           1            2                3             4   \
# 0              peer  mentorship      program        excellent        mentor
# 1             right      eating     disorder        dietitian       crucial
# 2    @beanbaghealth        word        pilot  self-compassion         issue
# 3       @sofiehagen       don't  waterstones             book       offence
# 4     @olvisredoubt    disorder       people             body          hard
# ..              ...         ...          ...              ...           ...
# 692         someone     calorie       you've        behaviour        praise
# 693           happy        year         year            bitch          frfr
# 694     @libero_mag        easy     disorder         recovery     difficult
# 695            easy    disorder     recovery        difficult  relationship
# 696            time    disorder        order          society          most
#
# ...

# %%
result = result.apply(lambda x:x.split()).to_list()
result
# Out:
# [['@bl00dyknuckl35',
#   'boys',
#   'masc',
#   'thinspo',
#   'cause',
#   'little',
#   'edtwt',
#   'appreciated'],
#  ['@369diet',
#   'essa',
#   'foto',
#   'prova',
#   'magra',
#   'normal',
#   'thinspo',
#   'TODA',
#   'diferença'],
#  ['@zakispo',
#   'nspo',
#   'height',
#   '143cm',
#   '165cm',
#   'appreciated',
#   'edtwt',
#   'eedeetwt',
#   'thinspo',
#   'anatwt',
#   'ricecake',
#   'ricecaketwt',
#   'calzonetwt'],
#  ['@k_thinspo'],
#  ['@loya12u', 'thinspo', 'thread', 'some', 'nsfw'],
#  ['Lēsl',
#   'Fitzg',
#   '3rāld',
#   'edtwt',
#   'meanspo',
#   'graça',
#   'thinspo',
#   'total',
#   'p3nny',
#   'juntos',
#   'grupo',
#   'caçoar',
#   'g0rd0',
#   'zapzap',
#   'estiloso',
#   'horas',
#   'come',
#   'pouco'],
#  ['C4rriē',
#   'Krūg',
#   'shtwt',
#   'goretwt',
#   'yantwt',
#   'gore',
#   'suicidio',
#   'beans',
#   'styro',
#   'gótica',
#   'thinspo',
#   'odeia',
#   'amigas',
#   'd4rw1n',
#   'cuida',
#   'cortes',
#   'namorado',
# ...

# %%
topic_modeling = TopicModeling(result)

ldamodel = topic_modeling.lda()
topics = topic_modeling.get_topics(ldamodel)

# %%
import pyLDAvis.gensim_models

pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(
    ldamodel, topic_modeling.corpus, topic_modeling.dictionary
)
pyLDAvis.display(vis)
# Out:
# /Library/Python/3.8/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   default_term_info = default_term_info.sort_values(
# /Library/Python/3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Library/Python/3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /Library/Python/3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# ...
